# %% [markdown]
# 1️⃣ Load data

# %% [markdown]
# 2️⃣ Basic overview (shape, head)

# %% [markdown]
# 3️⃣ Data types

# %% [markdown]
# 4️⃣ Missing values

# %% [markdown]
# 5️⃣ Duplicates

# %% [markdown]
# 6️⃣ Range checks (sales, profit, discount)

# %% [markdown]
# 7️⃣ Date consistency

# %% [markdown]
# 8️⃣ Initial conclusions (texto, no código)
